# %% [markdown]
# # From test prompts to LLM answers
#
# This notebook implements the execution of a scenario (prompts) designed in *stc-rdf-test*.
#
# Note : The code in the cells bellow should be added in a main function to be executed in command line.

# %%
import sys
print(sys.version)
import ollama
import pandas as pd
from pathlib import Path
from llms_classes import *
from prompt_classes import *
from dataset_classes import TextDataset
from matrix_creation_classes import *


text_dataset=TextDataset("/Users/marco/Documents/GitHub/FrameworkArgomentativo/argumentative_graph/Argument_Mining/dataset_input/test_text_class.csv")


text_dataset.filter_dataset_notclass()


prompt=PromptCreation(False, "/Users/marco/Documents/GitHub/FrameworkArgomentativo/argumentative_graph/Argument_Mining/dataset_input/test_prompts.csv","/Users/marco/Documents/GitHub/FrameworkArgomentativo/argumentative_graph/Argument_Mining/dataset_input/samples_fewshot.csv")


resulting_prompt=prompt.prompt_creation()


MODEL = "llama3.1:latest"
#MODEL= "mistral"
#MODEL = "qwen2.5"

# Init the ollama server
ollama_server = OllamaServer(ollama)

# Check models that have already been downloaded
models = ollama_server.get_models_list()
print("Available Models:", models)

# Download the model to use for experiences
models = ollama_server.download_model_if_not_exists(MODEL)

# Initialize the client and server
ollama_server = OllamaServer(ollama)

# Initialize chat with a specific model
chat = OllamaChat(server=ollama_server, model=MODEL)


matrix_creation=matrix_creation(chat, resulting_prompt)


obj=triple_extraction("/Users/marco/Documents/GitHub/FrameworkArgomentativo/argumentative_graph/arg_dic.json")

tupla=obj.extract_list_tuple()


triple = {
   "a": "A degree is important but not necessary, often companies also want people that have better work ethics and more work experience instead of academic knowledge.",
   "b": "I don't think that the number of students will be significantly reduced by paid studies. If someone is determined to study then he will find financial resources for the payment even if he has to find a float or take a loan",
   "c": "Education is important not only from an individual point of view, but also for society. Everyone should be encouraged to go to university. Maybe student loans need to be reframed to the student saying thank you when they can afford to do so."
}

matrix_support=matrix_creation.calculate_matrix(triple)
# Out:
# 3.13.2 (v3.13.2:4f8bb3947cf, Feb  4 2025, 11:51:10) [Clang 15.0.0 (clang-1500.3.9.4)]
# Available Models: ['llama3.1:latest', 'qwen2.5:latest', 'deepseek-r1:7b', 'llama3.2:3b', 'gemma2:2b', 'gemma2:latest', 'phi3.5:latest', 'qwen2:latest', 'phi3:latest', 'tinyllama:latest', 'qwen2:1.5b', 'qwen2:0.5b', 'llama3:latest']
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success
# ################## PROMPT #####################
# You are a model that evaluates how much an argument supports another. Given two arguments A and B, rate the degree to which Argument A supports Argument B on a scale from 0 to 1, where 0 means no support and 1 means complete support. Respond only with the numerical value. Do not print the <think> part.
#
# Argument A: A degree is important but not necessary, often companies also want people that have better work ethics and more work experience instead of academic knowledge.
# Argument B: I don't think that the number of students will be significantly reduced by paid studies. If someone is determined to study then he will find financial resources for the payment even if he has to find a float or take a loan
# Support value:
#
# ################## RESPONSE #####################
# Pred
# 0.75
#
# True
#
#
# ################## PROMPT #####################
# You are a model that evaluates how much an argument supports another. Given two arguments A and B, rate the degree to which Argument A supports Argument B on a scale from 0 to 1, where 0 means no support and 1 means complete support. Respond only with the numerical value. Do not print the <think> part.
#
# Argument A: A degree is important but not necessary, often companies also want people that have better work ethics and more work experience instead of academic knowledge.
# Argument B: Education is important not only from an individual point of view, but also for society. Everyone should be encouraged to go to university. Maybe student loans need to be reframed to the student saying thank you when they can afford to do so.
# Support value:
#
# ################## RESPONSE #####################
# Pred
# 0.65
#
# True
#
#
# ################## PROMPT #####################
# You are a model that evaluates how much an argument supports another. Given two arguments A and B, rate the degree to which Argument A supports Argument B on a scale from 0 to 1, where 0 means no support and 1 means complete support. Respond only with the numerical value. Do not print the <think> part.
#
# Argument A: I don't think that the number of students will be significantly reduced by paid studies. If someone is determined to study then he will find financial resources for the payment even if he has to find a float or take a loan
# Argument B: A degree is important but not necessary, often companies also want people that have better work ethics and more work experience instead of academic knowledge.
# Support value:
#
# ################## RESPONSE #####################
# Pred
# 0.95
#
# True
#
#
# ################## PROMPT #####################
# You are a model that evaluates how much an argument supports another. Given two arguments A and B, rate the degree to which Argument A supports Argument B on a scale from 0 to 1, where 0 means no support and 1 means complete support. Respond only with the numerical value. Do not print the <think> part.
#
# Argument A: I don't think that the number of students will be significantly reduced by paid studies. If someone is determined to study then he will find financial resources for the payment even if he has to find a float or take a loan
# Argument B: Education is important not only from an individual point of view, but also for society. Everyone should be encouraged to go to university. Maybe student loans need to be reframed to the student saying thank you when they can afford to do so.
# Support value:
#
# ################## RESPONSE #####################
# Pred
# 0.55
#
# True
#
#
# ################## PROMPT #####################
# You are a model that evaluates how much an argument supports another. Given two arguments A and B, rate the degree to which Argument A supports Argument B on a scale from 0 to 1, where 0 means no support and 1 means complete support. Respond only with the numerical value. Do not print the <think> part.
#
# Argument A: Education is important not only from an individual point of view, but also for society. Everyone should be encouraged to go to university. Maybe student loans need to be reframed to the student saying thank you when they can afford to do so.
# Argument B: A degree is important but not necessary, often companies also want people that have better work ethics and more work experience instead of academic knowledge.
# Support value:
#
# ################## RESPONSE #####################
# Pred
# 0.3
#
# True
#
#
# ################## PROMPT #####################
# You are a model that evaluates how much an argument supports another. Given two arguments A and B, rate the degree to which Argument A supports Argument B on a scale from 0 to 1, where 0 means no support and 1 means complete support. Respond only with the numerical value. Do not print the <think> part.
#
# Argument A: Education is important not only from an individual point of view, but also for society. Everyone should be encouraged to go to university. Maybe student loans need to be reframed to the student saying thank you when they can afford to do so.
# Argument B: I don't think that the number of students will be significantly reduced by paid studies. If someone is determined to study then he will find financial resources for the payment even if he has to find a float or take a loan
# Support value:
#
# ################## RESPONSE #####################
# Pred
# 0.8
#
# True
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 55
#      48 triple = {
#      49    "a": "A degree is important but not necessary, often companies also want people that have better work ethics and more work experience instead of academic knowledge.",
#      50    "b": "I don't think that the number of students will be significantly reduced by paid studies. If someone is determined to study then he will find financial resources for the payment even if he has to find a float or take a loan",
#      51    "c": "Education is important not only from an individual point of view, but also for society. Everyone should be encouraged to go to university. Maybe student loans need to be reframed to the student saying thank you when they can afford to do so."
#      52 }
#      54 matrix_support=matrix_creation.calculate_matrix(triple)
# ---> 55 obj=triple_extraction("/Users/marco/Documents/GitHub/FrameworkArgomentativo/argumentative_graph(arg_dic.json")
#      57 tupla=obj.extract_list_tuple()
#
# File ~/Documents/GitHub/FrameworkArgomentativo/argumentative_graph/Argument_Mining/matrix_creation_classes.py:44, in triple_extraction.__init__(self, file_path)
#      42 def __init__(self, file_path):
# ---> 44     with open(file_path, 'r') as f:
#      45         data = json.load(f)
#      47     self.data=data
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/marco/Documents/GitHub/FrameworkArgomentativo/argumentative_graph(arg_dic.json'

# %%
print(tupla)
